# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer

# Load dataset
data = load_breast_cancer()
X, y = data.data, data.target

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2
)

# Train model
model = xgb.XGBClassifier()
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9824561403508771

# %%
# !python -m pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (3.2.0)
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from xgboost) (2.2.6)
# Requirement already satisfied: scipy in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from xgboost) (1.15.3)
