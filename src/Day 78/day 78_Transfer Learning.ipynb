# %%
#Install Libraries
# !pip install opencv-python matplotlib
# Out:
# Requirement already satisfied: opencv-python in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (3.10.7)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=8 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: six>=1.5 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#import libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
#Load Image
img = cv2.imread("B:\AIML Internship\src\Day 78\cat.png")   # Replace with your image
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title("Original Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1023.5), np.float64(573.5), np.float64(-0.5))

# %%
#Image Masking
mask = np.zeros(img.shape[:2], dtype="uint8")

h, w = mask.shape
center = (w//2, h//2)
radius = 100

cv2.circle(mask, center, radius, 255, -1)

masked = cv2.bitwise_and(img, img, mask=mask)

plt.imshow(masked)
plt.title("Circular Mask Applied")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1023.5), np.float64(573.5), np.float64(-0.5))

# %%
#Color Channel Splitting
b, g, r = cv2.split(img)

plt.figure(figsize=(10,4))

plt.subplot(1,3,1)
plt.imshow(r, cmap='Reds')
plt.title("Red Channel")

plt.subplot(1,3,2)
plt.imshow(g, cmap='Greens')
plt.title("Green Channel")

plt.subplot(1,3,3)
plt.imshow(b, cmap='Blues')
plt.title("Blue Channel")
# Out:
# Text(0.5, 1.0, 'Blue Channel')

# %%
#Histogram Equalization 
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

equalized = cv2.equalizeHist(gray)

plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Original Gray")

plt.subplot(1,2,2)
plt.imshow(equalized, cmap='gray')
plt.title("Equalized Image")
# Out:
# Text(0.5, 1.0, 'Equalized Image')

# %%
#Image Blurring
gaussian = cv2.GaussianBlur(img, (5,5), 0)
median = cv2.medianBlur(img, 5)
bilateral = cv2.bilateralFilter(img, 9, 75, 75)

plt.figure(figsize=(10,6))

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original")

plt.subplot(2,2,2)
plt.imshow(gaussian)
plt.title("Gaussian")

plt.subplot(2,2,3)
plt.imshow(median)
plt.title("Median")

plt.subplot(2,2,4)
plt.imshow(bilateral)
plt.title("Bilateral")
# Out:
# Text(0.5, 1.0, 'Bilateral')

# %%
#Canny Edge Detection 
edges = cv2.Canny(gray, 100, 200)

plt.imshow(edges, cmap='gray')
plt.title("Canny Edge Detection")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1023.5), np.float64(573.5), np.float64(-0.5))
