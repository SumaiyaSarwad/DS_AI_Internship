# %%
# !pip install langchain langchain-openai chromadb renumics-spotlight pandas numpy
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
os.environ["OPENAI_API_KEY"] = "api_key = "YOUR_API_KEY""

# %%
from langchain_openai import OpenAIEmbeddings

embeddings_model = OpenAIEmbeddings(
    model="text-embedding-ada-002"
)

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

embeddings_model = OpenAIEmbeddings(
    model="text-embedding-ada-002"
)

docs_vectorstore = Chroma(
    collection_name="docs_store",
    embedding_function=embeddings_model,
    persist_directory="docs-db",
)
# Out:
# C:\Users\sumai\AppData\Local\Temp\ipykernel_17800\752160124.py:8: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the `langchain-chroma package and should be used instead. To use it run `pip install -U `langchain-chroma` and import as `from `langchain_chroma import Chroma``.
#   docs_vectorstore = Chroma(

# %%
# !pip install -U langchain langchain-community langchain-openai chromadb
# Out:
# ...
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 MB 330.3 kB/s eta 0:00:08
#      - -------------------------------------- 0.1/2.5 MB 901.1 kB/s eta 0:00:03
#      --- ------------------------------------ 0.2/2.5 MB 1.1 MB/s eta 0:00:03
#      ---- ----------------------------------- 0.3/2.5 MB 1.4 MB/s eta 0:00:02
#      ------ --------------------------------- 0.4/2.5 MB 1.6 MB/s eta 0:00:02
#      -------- ------------------------------- 0.5/2.5 MB 1.7 MB/s eta 0:00:02
#      ---------- ----------------------------- 0.6/2.5 MB 1.8 MB/s eta 0:00:02
#      ------------ --------------------------- 0.8/2.5 MB 1.9 MB/s eta 0:00:01
#      -------------- ------------------------- 0.9/2.5 MB 2.1 MB/s eta 0:00:01
#      ---------------- ----------------------- 1.0/2.5 MB 2.1 MB/s eta 0:00:01
# ...

# %%
# !pip install -U langchain-chroma
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install -U sentence-transformers langchain-huggingface
# Out:
# ...
#      ---------------------------------------- 0.0/588.7 kB ? eta -:--:--
#       --------------------------------------- 10.2/588.7 kB ? eta -:--:--
#       --------------------------------------- 10.2/588.7 kB ? eta -:--:--
#      - ----------------------------------- 30.7/588.7 kB 186.2 kB/s eta 0:00:03
#      - ----------------------------------- 30.7/588.7 kB 186.2 kB/s eta 0:00:03
#      --- --------------------------------- 61.4/588.7 kB 233.8 kB/s eta 0:00:03
#      ---- -------------------------------- 71.7/588.7 kB 231.0 kB/s eta 0:00:03
#      ---- -------------------------------- 71.7/588.7 kB 231.0 kB/s eta 0:00:03
#      ---- -------------------------------- 71.7/588.7 kB 231.0 kB/s eta 0:00:03
#      ----- ------------------------------- 92.2/588.7 kB 218.5 kB/s eta 0:00:03
#      -------- --------------------------- 143.4/588.7 kB 293.9 kB/s eta 0:00:02
#      -------- --------------------------- 143.4/588.7 kB 293.9 kB/s eta 0:00:02
# ...

# %%
# !pip install -U tf-keras transformers sentence-transformers
# Out:
# ...
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.7 MB 393.8 kB/s eta 0:00:05
#      - -------------------------------------- 0.1/1.7 MB 375.8 kB/s eta 0:00:05
#      -- ------------------------------------- 0.1/1.7 MB 590.8 kB/s eta 0:00:03
#      --- ------------------------------------ 0.2/1.7 MB 612.6 kB/s eta 0:00:03
#      ----- ---------------------------------- 0.2/1.7 MB 962.7 kB/s eta 0:00:02
#      ----------- ---------------------------- 0.5/1.7 MB 1.5 MB/s eta 0:00:01
#      ----------- ---------------------------- 0.5/1.7 MB 1.5 MB/s eta 0:00:01
#      ----------- ---------------------------- 0.5/1.7 MB 1.5 MB/s eta 0:00:01
#      -------------------- ------------------- 0.9/1.7 MB 1.8 MB/s eta 0:00:01
#      --------------------- ------------------ 0.9/1.7 MB 1.9 MB/s eta 0:00:01
# ...

# %%
# !pip uninstall -y transformers sentence-transformers torch torchvision torchaudio
# Out:
# Found existing installation: transformers 5.8.1
# Uninstalling transformers-5.8.1:
#   Successfully uninstalled transformers-5.8.1
# Found existing installation: sentence-transformers 5.5.0
# Uninstalling sentence-transformers-5.5.0:
#   Successfully uninstalled sentence-transformers-5.5.0
# Found existing installation: torch 2.4.1
# Uninstalling torch-2.4.1:
#   Successfully uninstalled torch-2.4.1
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\commands\uninstall.py", line 110, in run
#     uninstall_pathset.commit()
#   File "C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\req\req_uninstall.py", line 424, in commit
#     self._moved_paths.commit()
# ...

# %%
# !pip install torch==2.2.2
# !pip install transformers==4.41.2
# !pip install sentence-transformers==2.7.0
# !pip install langchain-huggingface
# !pip install langchain-chroma
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

embeddings_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

docs_vectorstore = Chroma(
    collection_name="docs_store",
    embedding_function=embeddings_model,
    persist_directory="docs-db",
)

print("RAG system ready!")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
# ...

# %%
docs_vectorstore.add_texts([
    "Artificial Intelligence helps machines learn patterns.",
    "Deepfake detection is important in digital forensics.",
    "RAG stands for Retrieval Augmented Generation."
])

print("Texts added successfully!")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 docs_vectorstore.add_texts([
#       2     "Artificial Intelligence helps machines learn patterns.",
#       3     "Deepfake detection is important in digital forensics.",
#       4     "RAG stands for Retrieval Augmented Generation."
#       5 ])
#       7 print("Texts added successfully!")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\langchain_chroma\vectorstores.py:627, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     625 texts = list(texts)
#     626 if self._embedding_function is not None:
# --> 627     embeddings = self._embedding_function.embed_documents(texts)
#     628 if metadatas:
#     629     # fill metadatas with empty dicts if somebody
#     630     # did not specify metadata for all texts
#     631     length_diff = len(texts) - len(metadatas)
#
# ...

# %%
# !pip uninstall -y numpy
# Out:
# Found existing installation: numpy 2.2.6
# Uninstalling numpy-2.2.6:
#   Successfully uninstalled numpy-2.2.6
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\cli\base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\commands\uninstall.py", line 110, in run
#     uninstall_pathset.commit()
#   File "C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\req\req_uninstall.py", line 424, in commit
#     self._moved_paths.commit()
#   File "C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\req\req_uninstall.py", line 277, in commit
#     save_dir.cleanup()
#   File "C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\site-packages\pip\_internal\utils\temp_dir.py", line 173, in cleanup
# ...

# %%
# !pip install numpy==1.26.4
# Out:
# ...
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.8 MB 1.4 MB/s eta 0:00:12
#      ---------------------------------------- 0.1/15.8 MB 1.8 MB/s eta 0:00:09
#       --------------------------------------- 0.2/15.8 MB 2.0 MB/s eta 0:00:08
#       --------------------------------------- 0.4/15.8 MB 2.2 MB/s eta 0:00:07
#      - -------------------------------------- 0.5/15.8 MB 2.2 MB/s eta 0:00:08
#      - -------------------------------------- 0.6/15.8 MB 2.4 MB/s eta 0:00:07
#      - -------------------------------------- 0.7/15.8 MB 2.4 MB/s eta 0:00:07
#      -- ------------------------------------- 0.9/15.8 MB 2.6 MB/s eta 0:00:06
#      -- ------------------------------------- 1.1/15.8 MB 2.7 MB/s eta 0:00:06
#      --- ------------------------------------ 1.2/15.8 MB 2.7 MB/s eta 0:00:06
#      --- ------------------------------------ 1.4/15.8 MB 2.9 MB/s eta 0:00:06
# ...

# %%
import numpy as np

print(np.__version__)
# Out:
# 1.26.4

# %%
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings

embeddings_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

docs_vectorstore = Chroma(
    collection_name="docs_store",
    embedding_function=embeddings_model,
    persist_directory="docs-db",
)
# Out:
# C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
docs_vectorstore.add_texts([
    "Artificial Intelligence helps machines learn patterns.",
    "Deepfake detection is important in digital forensics.",
    "RAG stands for Retrieval Augmented Generation."
])

print("Texts added successfully!")
# Out:
# Texts added successfully!

# %%
results = docs_vectorstore.similarity_search(
    "What is deepfake detection?"
)

for r in results:
    print(r.page_content)
    print("-" * 50)
# Out:
# Deepfake detection is important in digital forensics.
# --------------------------------------------------
# Artificial Intelligence helps machines learn patterns.
# --------------------------------------------------
# RAG stands for Retrieval Augmented Generation.
# --------------------------------------------------

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="gpt2"
)

query = "What is deepfake detection?"

results = docs_vectorstore.similarity_search(query)

context = "\n".join([r.page_content for r in results])

prompt = f"""
Context:
{context}

Question:
{query}

Answer:
"""

response = generator(
    prompt,
    max_new_tokens=50
)

print(response[0]["generated_text"])
# Out:
# WARNING:tensorflow:From C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# C:\Users\sumai\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\sumai\.cache\huggingface\hub\models--gpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...
