# %%
print("Simple AI Chatbot")
print("Type 'bye' to stop\n")

while True:
    user = input("You: ").lower()

    if user == "bye":
        print("Bot: Goodbye!")
        break

    elif "hello" in user or "hi" in user:
        print("Bot: Hello! How are you?")

    elif "your name" in user:
        print("Bot: I am a Python chatbot.")

    elif "how are you" in user:
        print("Bot: I'm doing great!")

    elif "ai" in user:
        print("Bot: AI means Artificial Intelligence.")

    else:
        print("Bot: Sorry, I don't understand.")
# Out:
# Simple AI Chatbot
# Type 'bye' to stop
# You:  hi
# Bot: Hello! How are you?
# You:  name?
# Bot: Sorry, I don't understand.
# You:  bye
# Bot: Goodbye!

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-2.37.0-py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.3 MB 262.6 kB/s eta 0:00:05
#      -- ------------------------------------- 0.1/1.3 MB 655.4 kB/s eta 0:00:02
#      ------ --------------------------------- 0.2/1.3 MB 1.1 MB/s eta 0:00:01
#      -------- ------------------------------- 0.3/1.3 MB 1.3 MB/s eta 0:00:01
#      ------------ --------------------------- 0.4/1.3 MB 1.5 MB/s eta 0:00:01
#      ----------------- ---------------------- 0.6/1.3 MB 1.8 MB/s eta 0:00:01
#      -------------------- ------------------- 0.7/1.3 MB 1.8 MB/s eta 0:00:01
#      ------------------------ --------------- 0.8/1.3 MB 1.9 MB/s eta 0:00:01
#      --------------------------- ------------ 0.9/1.3 MB 1.9 MB/s eta 0:00:01
#      ------------------------------ --------- 1.0/1.3 MB 1.9 MB/s eta 0:00:01
#      -------------------------------- ------- 1.1/1.3 MB 2.0 MB/s eta 0:00:01
#      ---------------------------------- ----- 1.1/1.3 MB 1.9 MB/s eta 0:00:01
#      -------------------------------------- - 1.3/1.3 MB 1.9 MB/s eta 0:00:01
#      ---------------------------------------- 1.3/1.3 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: tqdm>4 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.12.0)
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting jiter<1,>=0.10.0
#   Downloading jiter-0.14.0-cp310-cp310-win_amd64.whl (204 kB)
#      ---------------------------------------- 0.0/204.6 kB ? eta -:--:--
#      ---------------------------- --------- 153.6/204.6 kB 4.6 MB/s eta 0:00:01
#      -------------------------------------- 204.6/204.6 kB 3.1 MB/s eta 0:00:00
# Collecting sniffio
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from openai) (2.13.0)
# Requirement already satisfied: idna>=2.8 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.3.1)
# Requirement already satisfied: certifi in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: pydantic-core==2.46.0 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.46.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: colorama in c:\users\sumai\appdata\local\programs\python\python310\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Installing collected packages: sniffio, jiter, distro, openai
# Successfully installed distro-1.9.0 jiter-0.14.0 openai-2.37.0 sniffio-1.3.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
