# %%
# !pip install opencv-python
# Out:
# ...
#      ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#      ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#      --------------------------------------- 0.1/40.2 MB 825.8 kB/s eta 0:00:49
#      ---------------------------------------- 0.1/40.2 MB 1.0 MB/s eta 0:00:39
#      ---------------------------------------- 0.3/40.2 MB 1.9 MB/s eta 0:00:21
#       --------------------------------------- 0.5/40.2 MB 2.6 MB/s eta 0:00:16
#       --------------------------------------- 0.8/40.2 MB 3.4 MB/s eta 0:00:12
#      - -------------------------------------- 1.0/40.2 MB 3.5 MB/s eta 0:00:12
#      - -------------------------------------- 1.1/40.2 MB 3.7 MB/s eta 0:00:11
#      - -------------------------------------- 1.4/40.2 MB 3.7 MB/s eta 0:00:11
#      - -------------------------------------- 1.4/40.2 MB 3.4 MB/s eta 0:00:12
#      - -------------------------------------- 1.7/40.2 MB 3.6 MB/s eta 0:00:11
# ...

# %%
import cv2

img = cv2.imread("6941948.jpg")

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2.imwrite("gray.jpg", gray)

cv2.imshow("Gray Image", gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread("6941948.jpg")

blur = cv2.GaussianBlur(img, (5,5), 0)

cv2.imwrite("gaussian_blur.jpg", blur)

plt.imshow(cv2.cvtColor(blur, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread("6941948.jpg")

edges = cv2.Canny(img, 100, 200)

cv2.imwrite("edges.jpg", edges)

plt.imshow(edges, cmap='gray')
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("6941948.jpg", 0)

kernel = np.ones((5,5), np.uint8)

erosion = cv2.erode(img, kernel)

cv2.imwrite("erosion.jpg", erosion)

plt.imshow(erosion, cmap='gray')
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("6941948.jpg", 0)

kernel = np.ones((5,5), np.uint8)

dilation = cv2.dilate(img, kernel)

cv2.imwrite("dilation.jpg", dilation)

plt.imshow(dilation, cmap='gray')
plt.axis('off')
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread("6941948.jpg")

resized = cv2.resize(img, (300, 300))

cv2.imwrite("resized.jpg", resized)

plt.imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt

img = cv2.imread("6941948.jpg", 0)

equalized = cv2.equalizeHist(img)

cv2.imwrite("equalized.jpg", equalized)

plt.imshow(equalized, cmap='gray')
plt.axis('off')
plt.show()
